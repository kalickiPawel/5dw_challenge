# %%
from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
from keras.preprocessing import image
import numpy as np

import requests
from io import BytesIO
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From /Users/kalickipawel/anaconda3/envs/python36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ![](https://www.docusign.com.au/blog/wp-content/uploads/sites/13/2014/10/shutterstock_106224893_03-720x678.jpg)

# %%
url_img = 'https://www.docusign.com.au/blog/wp-content/uploads/sites/13/2014/10/shutterstock_106224893_03-720x678.jpg'

response = requests.get(url_img)
img = Image.open( BytesIO(response.content) )
img = img.resize( (224, 224) )
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0xB414BB438>

# %%
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred, top=3)
# Out:
# [[('n04286575', 'spotlight', 0.42007366),
#   ('n03666591', 'lighter', 0.15656027),
#   ('n04456115', 'torch', 0.13311754)]]
